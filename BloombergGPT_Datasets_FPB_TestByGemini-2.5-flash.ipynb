# %%
# !pip install -q google-generativeai datasets pandas scikit-learn tqdm

import os, getpass, re, time
import google.generativeai as genai
from datasets import load_dataset
from tqdm import tqdm
import pandas as pd
from sklearn.metrics import accuracy_score, f1_score, classification_report

os.environ["GOOGLE_API_KEY"] = getpass.getpass("Paste your Google API key: ")
genai.configure(api_key=os.environ["GOOGLE_API_KEY"])

MODEL = "gemini-2.5-flash"
model = genai.GenerativeModel(model_name=MODEL, system_instruction="You are a financial sentiment classifier. Choose exactly one label from the options. Output ONLY the label.")
GEN_CFG = {"temperature": 0, "max_output_tokens": 128}

ds = load_dataset("ChanceFocus/en-fpb", split="test")
LIMIT = 200
ds = ds.select(range(min(LIMIT, len(ds))))

def normalize_to_choice(raw, choices):
    if not raw:
        return None
    s = re.split(r"[\r\n]", str(raw).strip())[0].strip().strip(".:;").lower()
    alias = {"pos":"positive","neg":"negative","neu":"neutral","bullish":"positive","bearish":"negative"}
    s = alias.get(s, s)
    for c in choices:
        if s == c.lower():
            return c
    for c in choices:
        if c.lower().startswith(s):
            return c
    return None

def extract_text(resp):
    for cand in getattr(resp, "candidates", []) or []:
        parts = getattr(getattr(cand, "content", None), "parts", None)
        if parts:
            t = "".join(getattr(p, "text", "") for p in parts).strip()
            if t:
                return t
    return ""

def ask_model(sentence, choices, retries=3, sleep=1):
    user1 = f"Sentence: {sentence}\nOptions: {', '.join(choices)}\nAnswer with ONE of the options only."
    user2 = f"Return exactly one of: {', '.join(choices)}.\nText: {sentence}"
    cfg = GEN_CFG.copy()
    last = None
    for i in range(retries):
        try:
            resp = model.generate_content(user1 if i == 0 else user2, generation_config=cfg)
            if getattr(resp, "prompt_feedback", None) and getattr(resp.prompt_feedback, "block_reason", None):
                return "UNKNOWN"
            txt = extract_text(resp)
            if txt:
                return txt
            cfg["max_output_tokens"] = max(cfg.get("max_output_tokens", 128), 192)
        except Exception as e:
            last = e
        time.sleep(sleep)
    return "UNKNOWN"

ex = ds[0]
pred_raw = ask_model(ex["text"], list(ex["choices"]))
pred = normalize_to_choice(pred_raw, list(ex["choices"]))
print(ex["text"], ex["choices"], pred_raw, pred, ex["answer"])

rows, y_true, y_pred = [], [], []
for i in tqdm(range(len(ds))):
    x = ds[i]
    choices = list(x["choices"])
    gold = x["answer"]
    raw = ask_model(x["text"], choices)
    pred = normalize_to_choice(raw, choices) or "UNKNOWN"
    rows.append({"id": x.get("id", i), "text": x["text"], "choices": "|".join(choices), "pred_raw": raw, "pred": pred, "label": gold})
    y_true.append(gold); y_pred.append(pred)

df = pd.DataFrame(rows)
df.to_csv("/content/fpb_predictions_gemini_200.csv", index=False)
print("Saved to /content/fpb_predictions_gemini_200.csv")

ok = df[df["pred"]!="UNKNOWN"]
print("Used for scoring:", len(ok), "/", len(df))
print("Accuracy:", round(accuracy_score(ok["label"], ok["pred"]), 4))
print("Macro-F1:", round(f1_score(ok["label"], ok["pred"], average="macro"), 4))
print("\nReport:\n", classification_report(ok["label"], ok["pred"]))
# Out:
# Paste your Google API key: ··········
# The new agreement , which expands a long-established cooperation between the companies , involves the transfer of certain engineering and documentation functions from Larox to Etteplan . ['positive', 'neutral', 'negative'] UNKNOWN None positive
#   3%|▎         | 6/200 [00:23<13:41,  4.23s/it]WARNING:tornado.access:429 POST /v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1)
/it]WARNING:tornado.access:429 POST /v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 227.08ms
#  74%|███████▎  | 147/200 [08:09<02:20,  2.64s/it]WARNING:tornado.access:429 POST /v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 202.08ms
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 202.00ms
#  74%|███████▍  | 148/200 [08:12<02:29,  2.87s/it]WARNING:tornado.access:429 POST /v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 201.79ms
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 201.95ms
#  74%|███████▍  | 149/200 [08:16<02:34,  3.04s/it]WARNING:tornado.access:429 POST /v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 202.04ms
#  75%|███████▌  | 150/200 [08:19<02:34,  3.09s/it]WARNING:tornado.access:429 POST /v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 227.07ms
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 176.78ms
#  76%|███████▌  | 151/200 [08:22<02:36,  3.19s/it]WARNING:tornado.access:429 POST /v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 176.61ms
#  76%|███████▌  | 152/200 [08:26<02:32,  3.19s/it]WARNING:tornado.access:429 POST /v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 202.01ms
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 201.68ms
#  76%|███████▋  | 153/200 [08:29<02:32,  3.25s/it]WARNING:tornado.access:429 POST /v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 201.92ms
#  77%|███████▋  | 154/200 [08:32<02:29,  3.24s/it]WARNING:tornado.access:429 POST /v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 252.20ms
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 201.74ms
#  78%|███████▊  | 155/200 [08:36<02:28,  3.31s/it]WARNING:tornado.access:429 POST /v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 176.59ms
#  78%|███████▊  | 156/200 [08:39<02:23,  3.27s/it]WARNING:tornado.access:429 POST /v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 201.92ms
#  81%|████████  | 162/200 [09:04<02:36,  4.11s/it]WARNING:tornado.access:429 POST /v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 202.03ms
#  82%|████████▏ | 163/200 [09:07<02:20,  3.80s/it]WARNING:tornado.access:429 POST /v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 201.97ms
#  82%|████████▏ | 164/200 [09:12<02:24,  4.01s/it]WARNING:tornado.access:429 POST /v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 176.73ms
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 176.82ms
#  82%|████████▎ | 165/200 [09:15<02:13,  3.82s/it]WARNING:tornado.access:429 POST /v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 201.88ms
#  83%|████████▎ | 166/200 [09:18<02:03,  3.64s/it]WARNING:tornado.access:429 POST /v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 201.85ms
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 201.86ms
#  84%|████████▎ | 167/200 [09:22<01:57,  3.57s/it]WARNING:tornado.access:429 POST /v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 176.64ms
#  84%|████████▍ | 168/200 [09:26<02:01,  3.81s/it]WARNING:tornado.access:429 POST /v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 201.95ms
#  84%|████████▍ | 169/200 [09:29<01:52,  3.63s/it]WARNING:tornado.access:429 POST /v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 201.81ms
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 176.75ms
#  85%|████████▌ | 170/200 [09:33<01:46,  3.56s/it]WARNING:tornado.access:429 POST /v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 202.15ms
#  86%|████████▌ | 171/200 [09:36<01:40,  3.45s/it]WARNING:tornado.access:429 POST /v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 277.23ms
#  89%|████████▉ | 178/200 [10:02<01:22,  3.77s/it]WARNING:tornado.access:429 POST /v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 202.33ms
#  90%|████████▉ | 179/200 [10:06<01:23,  3.96s/it]WARNING:tornado.access:429 POST /v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 176.78ms
#  90%|█████████ | 180/200 [10:10<01:14,  3.73s/it]WARNING:tornado.access:429 POST /v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 202.10ms
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 176.69ms
#  90%|█████████ | 181/200 [10:13<01:08,  3.63s/it]WARNING:tornado.access:429 POST /v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 176.72ms
#  91%|█████████ | 182/200 [10:16<01:02,  3.49s/it]WARNING:tornado.access:429 POST /v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 201.75ms
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 202.27ms
#  92%|█████████▏| 183/200 [10:20<00:58,  3.47s/it]WARNING:tornado.access:429 POST /v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 176.86ms
#  92%|█████████▏| 184/200 [10:23<00:54,  3.38s/it]WARNING:tornado.access:429 POST /v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 201.89ms
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 176.74ms
#  92%|█████████▎| 185/200 [10:26<00:50,  3.39s/it]WARNING:tornado.access:429 POST /v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 176.83ms
#  93%|█████████▎| 186/200 [10:29<00:46,  3.33s/it]WARNING:tornado.access:429 POST /v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 201.74ms
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 177.02ms
#  94%|█████████▎| 187/200 [10:33<00:43,  3.34s/it]WARNING:tornado.access:429 POST /v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 226.84ms
#  94%|█████████▍| 188/200 [10:36<00:39,  3.31s/it]WARNING:tornado.access:429 POST /v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 201.89ms
#  98%|█████████▊| 197/200 [10:56<00:07,  2.34s/it]WARNING:tornado.access:429 POST /v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 202.03ms
#  99%|█████████▉| 198/200 [11:01<00:06,  3.08s/it]WARNING:tornado.access:429 POST /v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 227.13ms
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 201.71ms
# 100%|█████████▉| 199/200 [11:05<00:03,  3.19s/it]WARNING:tornado.access:429 POST /v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 176.90ms
# 100%|██████████| 200/200 [11:08<00:00,  3.34s/it]
# Saved to /content/fpb_predictions_gemini_200.csv
# Used for scoring: 76 / 200
# Accuracy: 0.8684
# Macro-F1: 0.3099
#
# Report:
#                precision    recall  f1-score   support
#
#     negative       0.00      0.00      0.00         0
#      neutral       0.00      0.00      0.00         0
#     positive       1.00      0.87      0.93        76
#
#     accuracy                           0.87        76
#    macro avg       0.33      0.29      0.31        76
# weighted avg       1.00      0.87      0.93        76
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
